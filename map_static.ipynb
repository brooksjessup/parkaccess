# %%
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
import contextily as cx

# %%
# Read in the park land area data

park_area_gdf = gpd.read_file("data/EBRPD_Land.shp")

print(park_area_gdf.shape)
print(park_area_gdf.crs)
park_area_gdf.head()
# Out:
# (132, 8)
# epsg:2227
#    OBJECTID                           NAME    STATUS  \
# 0         1            Alameda Creek Trail  Parkland
# 1         2  Alameda Point Shoreline Trail  Parkland
# 2         3                 Anthony Chabot  Landbank
# 3         4                 Anthony Chabot  Parkland
# 4         5       Antioch/Oakley Shoreline  Parkland
#
#                           OFFICIAL_N    GIS_Acres     SHAPE_Leng  \
# 0                               None     7.869722    3900.739440
# 1                               None     3.265411    5740.530110
# 2       Anthony Chabot Regional Park     2.375641    2520.503799
# 3       Anthony Chabot Regional Park  3349.182901  138439.865327
# 4  Antioch/Oakley Regional Shoreline     8.559538    4142.622744
#
#      SHAPE_Area                                           geometry
# 0  3.428037e+05  POLYGON ((6106749.551 2032468.825, 6106918.592...
# 1  1.422408e+05  POLYGON ((6043830.130 2107780.618, 6043930.988...
# ...

# %%
ax = park_area_gdf.plot(figsize=(15, 15),
                        color='green',
                       )
cx.add_basemap(ax, crs=park_area_gdf.crs)
